# %% [markdown]
# ## Most Frequst used method

# %% [markdown]
# <b>Pandas Library </b> is very useful for data processing & analysis. <b> Pandas DataFrame</b> is a two dimentional tabular data structure with labelled axis (rows and columns)
# <b> DataFrame </b> is a table of columns & rows in pandas what we can easily structure, filter, process for uses

# %%
import pandas as pd
import numpy as np # for generating numbers

# %% [markdown]
# #### Data Preperation - 1

# %%
data1 = np.random.randint(0, 101, (4, 3)) # value range (0 -100) 4 rows, 3 cols, random int numbers only
data1
# Out:
# array([[19, 35, 24],
#        [ 8, 85,  7],
#        [17, 79, 86],
#        [80, 96, 28]])

# %%
# random, row=100, col 8
data2 = np.random.randint(0,501, (100, 5))
data2.shape
# Out:
# (100, 5)

# %% [markdown]
# #### Data Preperation-2

# %%
my_index = ["Japan", "Bangladesh", "Nepal", "Bhutan"]
my_index
# Out:
# ['Japan', 'Bangladesh', 'Nepal', 'Bhutan']

# %%
column = ["Jan", "Feb", "Mar"]

# %%
df = pd.DataFrame(data1, index=my_index, columns=column)
df
# Out:
#             Jan  Feb  Mar
# Japan        19   35   24
# Bangladesh    8   85    7
# Nepal        17   79   86
# Bhutan       80   96   28

# %% [markdown]
# 1. data1: (4, 3) where my_index: 4 entries & column: 3   ( 4,3) so, we can build a dataframe/table when matched the shape, otherwise give "ValueError"

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### Get name of columns

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df2 = tips.rename(columns={'sex':'gender'})
df2
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Statistical Description

# %%
df2.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df2.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df2.describe().transpose()
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %% [markdown]
# ### To extract out single column or multiple column

# %%
df2[['gender']].head(3)
# Out:
#    gender
# 0  Female
# 1    Male
# 2    Male

# %%
df2[['gender','smoker']].head(3)
# Out:
#    gender smoker
# 0  Female     No
# 1    Male     No
# 2    Male     No

# %%
df2["day"]
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# ### How to drop column

# %%
# drop single column
df2.drop('size', axis=1)  # row-0; col-1, df2.drop('size', axis=1, inplace=True)
# Out:
#      total_bill   tip  gender smoker   day    time
# 0         16.99  1.01  Female     No   Sun  Dinner
# 1         10.34  1.66    Male     No   Sun  Dinner
# 2         21.01  3.50    Male     No   Sun  Dinner
# 3         23.68  3.31    Male     No   Sun  Dinner
# 4         24.59  3.61  Female     No   Sun  Dinner
# ..          ...   ...     ...    ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner
# 240       27.18  2.00  Female    Yes   Sat  Dinner
# 241       22.67  2.00    Male    Yes   Sat  Dinner
# 242       17.82  1.75    Male     No   Sat  Dinner
# 243       18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
# drop multiple column
df2.drop(['size', 'tip'], axis=1)
# Out:
#      total_bill  gender smoker   day    time
# 0         16.99  Female     No   Sun  Dinner
# 1         10.34    Male     No   Sun  Dinner
# 2         21.01    Male     No   Sun  Dinner
# 3         23.68    Male     No   Sun  Dinner
# 4         24.59  Female     No   Sun  Dinner
# ..          ...     ...    ...   ...     ...
# 239       29.03    Male     No   Sat  Dinner
# 240       27.18  Female    Yes   Sat  Dinner
# 241       22.67    Male    Yes   Sat  Dinner
# 242       17.82    Male     No   Sat  Dinner
# 243       18.78  Female     No  Thur  Dinner
#
# [244 rows x 5 columns]

# %% [markdown]
# ### How to set any column as index

# %%
df = df2.set_index("gender").head()  # set index
df
# Out:
#         total_bill   tip smoker  day    time  size
# gender
# Female       16.99  1.01     No  Sun  Dinner     2
# Male         10.34  1.66     No  Sun  Dinner     3
# Male         21.01  3.50     No  Sun  Dinner     3
# Male         23.68  3.31     No  Sun  Dinner     2
# Female       24.59  3.61     No  Sun  Dinner     4

# %%
df = df.reset_index()  # back to previous stage
df
# Out:
#    gender  total_bill   tip smoker  day    time  size
# 0  Female       16.99  1.01     No  Sun  Dinner     2
# 1    Male       10.34  1.66     No  Sun  Dinner     3
# 2    Male       21.01  3.50     No  Sun  Dinner     3
# 3    Male       23.68  3.31     No  Sun  Dinner     2
# 4  Female       24.59  3.61     No  Sun  Dinner     4

# %% [markdown]
# ### To select any specific rows with index position

# %%
df.iloc[0]
# Out:
# gender        Female
# total_bill     16.99
# tip             1.01
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# gender          Male
# total_bill     10.34
# tip             1.66
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 1, dtype: object

# %%
df.iloc[2]
# Out:
# gender          Male
# total_bill     21.01
# tip              3.5
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 2, dtype: object

# %%
df.iloc[4]
# Out:
# gender        Female
# total_bill     24.59
# tip             3.61
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 4, dtype: object

# %% [markdown]
# ### 10. Select subsection of dataframe

# %%
# row 1 to 5
df.iloc[1:5]
# Out:
#         gender  total_bill   tip smoker  day  size
# time
# Dinner    Male       10.34  1.66     No  Sun     3
# Dinner    Male       21.01  3.50     No  Sun     3
# Dinner    Male       23.68  3.31     No  Sun     2
# Dinner  Female       24.59  3.61     No  Sun     4

# %%
df.iloc[1, 3]
# Out:
# 'No'

# %%
df.iloc[:, 2:6]
# Out:
#     tip smoker  day    time
# 0  1.01     No  Sun  Dinner
# 1  1.66     No  Sun  Dinner
# 2  3.50     No  Sun  Dinner
# 3  3.31     No  Sun  Dinner
# 4  3.61     No  Sun  Dinner

# %%
df.iloc[:, 5:7]
# Out:
#      time  size
# 0  Dinner     2
# 1  Dinner     3
# 2  Dinner     3
# 3  Dinner     2
# 4  Dinner     4

# %%
df.iloc[3:5, :]
# Out:
#    gender  total_bill   tip smoker  day    time  size
# 3    Male       23.68  3.31     No  Sun  Dinner     2
# 4  Female       24.59  3.61     No  Sun  Dinner     4

# %%
df.iloc[:] # all rows & cols
# Out:
#    gender  total_bill   tip smoker  day    time  size
# 0  Female       16.99  1.01     No  Sun  Dinner     2
# 1    Male       10.34  1.66     No  Sun  Dinner     3
# 2    Male       21.01  3.50     No  Sun  Dinner     3
# 3    Male       23.68  3.31     No  Sun  Dinner     2
# 4  Female       24.59  3.61     No  Sun  Dinner     4

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#      gender  total_bill   tip smoker    time  size
# day
# Sun  Female       16.99  1.01     No  Dinner     2
# Sun    Male       10.34  1.66     No  Dinner     3
# Sun    Male       21.01  3.50     No  Dinner     3
# Sun    Male       23.68  3.31     No  Dinner     2
# Sun  Female       24.59  3.61     No  Dinner     4

# %%
df.shape
# Out:
# (5, 6)

# %%
# drop row
# df.drop('sun', axis=0)

# %%
df = pd.read_csv(r"E:\M60\ml_dataset\tips_v1.csv")
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# #### Q. Find the total bills greater than 40 dollars

# %%
# syntax:  var_name[var_name[col_name] condition]
df[df['total_bill']>45]
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 59        48.27   6.73  Male     No  Sat  Dinner     4
# 156       48.17   5.00  Male     No  Sun  Dinner     6
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3
# 212       48.33   9.00  Male     No  Sat  Dinner     4

# %% [markdown]
# #### Q. Find the number of male customer

# %%
df[df['sex']=="Male"]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %% [markdown]
# #### Q Find & count the number of male customer

# %%
df[df['sex']=='Male'].count()
# Out:
# total_bill    157
# tip           157
# sex           157
# smoker        157
# day           157
# time          157
# size          157
# dtype: int64

# %% [markdown]
# ### Continued....
